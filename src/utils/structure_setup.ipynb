# %%
# %sql
-- Create the Unity Catalog Structure
CREATE CATALOG IF NOT EXISTS brightgrid;
USE CATALOG brightgrid;
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

-- Create Volumes
CREATE VOLUME IF NOT EXISTS brightgrid.bronze.raw_readings;
CREATE VOLUME IF NOT EXISTS brightgrid.bronze.checkpoints;

# %%
# Create Seed Data
from src.utils.generate_readings import generate_batch;

generate_batch(n_meters=300, batch_id=1)
generate_batch(n_meters=250, batch_id=2)
generate_batch(n_meters=275, batch_id=3, fault_rate=0.12)
